# %% [markdown]
# # Bokeh

# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, show

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
from numpy import cos, linspace
x = linspace(-6,6,100)
y = cos(x)

# %%
p =figure(width=500, height=500)
p.circle(x,y,size=7, color='firebrick', alpha=.5)
show(p)
# Out:
#   <div class="bk-root" id="656ebd72-2d8b-4bb3-9dc5-0428e407b58b" data-root-id="1454"></div>

# %%
from bokeh.sampledata.autompg import autompg
grouped = autompg.groupby("yr")
grouped
mpg = grouped.mpg
avg, std = mpg.mean(), mpg.std()
years = list(grouped.groups)
american = autompg[autompg['origin']==1]
japanese = autompg[autompg['origin']==3]

# %%
p = figure(title="MPG by Year (Japan and US)")
p.vbar(x=years, bottom=avg-std, top=avg+std, width=0.8,
      fill_alpha=0.2, line_color=None, legend_label="MPG 1 std")
p.circle(x=japanese['yr'], y=japanese['mpg'], size=8, alpha=0.5, 
         color='red', legend_label="Japanese")
p.triangle(x=american['yr'], y=american['mpg'], size=8, alpha=0.5,
          color='blue', legend_label="American")
p.legend.location = 'top_left'
show(p)
# Out:
#   <div class="bk-root" id="fd6846ac-fbf6-45d5-b922-319233dc69b9" data-root-id="2058"></div>
